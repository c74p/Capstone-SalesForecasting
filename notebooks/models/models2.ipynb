# %%
import contextlib
from datetime import datetime
from fastai import *
from fastai.tabular import *
import io
import pandas as pd
from pathlib import Path
import random

# %%
DATA_PATH = Path('../../data/interim')
path = Path('../../models/')

# %%
#tester = pd.read_csv(DATA_PATH/'train_valid_data.csv', low_memory=False)
tester.head()
#print(sorted(tester.columns))
# ['assortment', 'cloud_cover', 'competition_distance', 'competition_open_since_month', 'competition_open_since_year', 'customers', 'date', 'day_of_week', 'dew_point_c', 'events', 'max_gust_speed_km_h', 'max_humidity', 'max_sea_level_pressureh_pa', 'max_temperature_c', 'max_visibility_km', 'max_wind_speed_km_h', 'mean_dew_point_c', 'mean_humidity', 'mean_sea_level_pressureh_pa', 'mean_temperature_c', 'mean_visibility_km', 'mean_wind_speed_km_h', 'min_dew_point_c', 'min_humidity', 'min_sea_level_pressureh_pa', 'min_temperature_c', 'min_visibility_km', 'open', 'precipitationmm', 'promo', 'promo2', 'promo2_since_week', 'promo2_since_year', 'promo_interval', 'sales', 'school_holiday', 'state', 'state_holiday', 'store', 'store_type', 'trend', 'week_start', 'wind_dir_degrees']

# Split out future columns
future_columns = ['cloud_cover', 'customers', 'dew_point_c', 'events', 'max_gust_speed_km_h', 'max_humidity',
                  'max_sea_level_pressureh_pa', 'max_temperature_c', 'max_visibility_km', 'max_wind_speed_km_h',
                  'mean_dew_point_c', 'mean_humidity', 'mean_sea_level_pressureh_pa', 'mean_temperature_c', 
                  'mean_visibility_km', 'mean_wind_speed_km_h', 'min_dew_point_c',  'min_humidity',
                  'min_sea_level_pressureh_pa', 'min_temperature_c', 'min_visibility_km', 'precipitationmm', 'sales', 
                  'trend', 'wind_dir_degrees']

known_columns = set(tester.columns) - set(future_columns)

print('Known: ', sorted(known_columns), '\n')
print('Unknown in future: ', sorted(future_columns))
# Out:
# Known:  ['assortment', 'competition_distance', 'competition_open_since_month', 'competition_open_since_year', 'date', 'day_of_week', 'open', 'promo', 'promo2', 'promo2_since_week', 'promo2_since_year', 'promo_interval', 'school_holiday', 'state', 'state_holiday', 'store', 'store_type', 'week_start']
#
# Unknown in future:  ['cloud_cover', 'customers', 'dew_point_c', 'events', 'max_gust_speed_km_h', 'max_humidity', 'max_sea_level_pressureh_pa', 'max_temperature_c', 'max_visibility_km', 'max_wind_speed_km_h', 'mean_dew_point_c', 'mean_humidity', 'mean_sea_level_pressureh_pa', 'mean_temperature_c', 'mean_visibility_km', 'mean_wind_speed_km_h', 'min_dew_point_c', 'min_humidity', 'min_sea_level_pressureh_pa', 'min_temperature_c', 'min_visibility_km', 'precipitationmm', 'sales', 'trend', 'wind_dir_degrees']

# %%
test_idx = range(int(0.8 * 100), 100)
#test_idx[0] # 80
#test_idx[-1] # 99
list(test_idx)
# Out:
# [80,
#  81,
#  82,
#  83,
#  84,
#  85,
#  86,
#  87,
#  88,
#  89,
#  90,
#  91,
#  92,
#  93,
#  94,
#  95,
#  96,
#  97,
#  98,
#  99]

# %%
# Import train_valid_data and test_data dataframes
train_valid_df_raw = pd.read_csv(DATA_PATH/'train_valid_data.csv', low_memory=False)
train_valid_df = train_valid_df_raw.copy()

# Sort by date since we'll want to split by date for train/validation sets
train_valid_df.sort_values('date')

# Drop week_start and day_of_week as they'll get taken into account by add_datepart() for date
train_valid_df.drop('week_start', axis='columns', inplace=True)
train_valid_df.drop('day_of_week', axis='columns', inplace=True)

# Drop any rows where sales = 0 since we don't need to forecast those
train_valid_df = train_valid_df[train_valid_df.sales != 0]

# Run tabular.add_datepart() on both dfs to add columns about the date: ['Year', 'Month', 'Week', 'Day', 'Dayofweek',
# 'Dayofyear', 'Is_month_end', 'Is_month_start', 'Is_quarter_end', 'Is_quarter_start', 'Is_year_end', 'Is_year_start']
tabular.add_datepart(train_valid_df, 'date', drop=True, time=False)

# Category names, to which we'll apply embeddings
cat_names = ['assortment', 'events', 'promo_interval', 'state', 'state_holiday', 'store_type']

# Add the date-related categories
cat_names += ['Day', 'Dayofweek', 'Is_month_end', 'Is_month_start', 'Is_quarter_end', 'Is_quarter_start', 'Is_year_end',
              'Is_year_start', 'Month', 'Week', 'Year',]

# Continuous-variable names, which we'll make sure are all represented as floats
# Just use set difference to make sure everything is covered
cont_names = list(set(train_valid_df.columns) - set(cat_names))

# Set up transforms to 1) replace missing values for continuous variables by the median column value, 2) transform all
# categorical variables into categories, 3) normalize continuous variables.
procs = [FillMissing, Categorify, Normalize]

df = train_valid_df

# Validation set is just 80% of the whole thing
valid_idx = range(int(0.8 * len(df)), len(df))
dep_var = 'sales'

# List out the features that we don't know for predictions
unknown_in_future = ['cloud_cover', 'customers', 'dew_point_c', 'events', 'max_gust_speed_km_h', 'max_humidity',
                     'max_sea_level_pressureh_pa', 'max_temperature_c', 'max_visibility_km', 'max_wind_speed_km_h',
                     'mean_dew_point_c', 'mean_humidity', 'mean_sea_level_pressureh_pa', 'mean_temperature_c', 
                     'mean_visibility_km', 'mean_wind_speed_km_h', 'min_dew_point_c',  'min_humidity',
                     'min_sea_level_pressureh_pa', 'min_temperature_c', 'min_visibility_km', 'precipitationmm', 'trend',
                     'wind_dir_degrees']

# List of features that we know for predictions
known_in_future = set(train_valid_df.columns) - set(unknown_in_future)

print('Known: ', sorted(known_in_future), '\n')

# Make sure that features we don't know for predictions are all marked as NA in the validation set
# Our FillMissing pre-processing will account for these
train_valid_df.loc[valid_idx[0]:valid_idx[-1], unknown_in_future] = np.NaN

data = (TabularList.from_df(df, path=path, cat_names=cat_names, cont_names=cont_names, procs=procs)
                   .split_by_idx(valid_idx)
                   .label_from_df(cols=dep_var, label_cls=FloatList, log=True)
                   .databunch())

data.show_batch()
# Out:
# <table>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <tr>
#     <th>assortment</th>
#     <th>events</th>
#     <th>promo_interval</th>
#     <th>state</th>
#     <th>state_holiday</th>
#     <th>store_type</th>
#     <th>Day</th>
#     <th>Dayofweek</th>
#     <th>Is_month_end</th>
#     <th>Is_month_start</th>
#     <th>Is_quarter_end</th>
#     <th>Is_quarter_start</th>
#     <th>Is_year_end</th>
#     <th>Is_year_start</th>
#     <th>Month</th>
#     <th>Week</th>
#     <th>Year</th>
#     <th>cloud_cover_na</th>
#     <th>trend_na</th>
#     <th>min_humidity_na</th>
#     <th>max_visibility_km_na</th>
#     <th>wind_dir_degrees_na</th>
#     <th>mean_visibility_km_na</th>
#     <th>max_gust_speed_km_h_na</th>
#     <th>dew_point_c_na</th>
#     <th>min_temperature_c_na</th>
#     <th>min_visibility_km_na</th>
#     <th>mean_humidity_na</th>
#     <th>max_sea_level_pressureh_pa_na</th>
#     <th>min_sea_level_pressureh_pa_na</th>
#     <th>max_wind_speed_km_h_na</th>
#     <th>max_humidity_na</th>
#     <th>mean_temperature_c_na</th>
#     <th>mean_dew_point_c_na</th>
#     <th>mean_wind_speed_km_h_na</th>
#     <th>max_temperature_c_na</th>
#     <th>precipitationmm_na</th>
#     <th>mean_sea_level_pressureh_pa_na</th>
#     <th>min_dew_point_c_na</th>
#     <th>customers_na</th>
#     <th>cloud_cover</th>
#     <th>competition_distance</th>
#     <th>trend</th>
#     <th>min_humidity</th>
#     <th>school_holiday</th>
#     <th>max_visibility_km</th>
#     <th>sales</th>
#     <th>promo2</th>
#     <th>wind_dir_degrees</th>
#     <th>mean_visibility_km</th>
#     <th>competition_open_since_year</th>
#     <th>Dayofyear</th>
#     <th>max_gust_speed_km_h</th>
#     <th>promo</th>
#     <th>dew_point_c</th>
#     <th>promo2_since_year</th>
#     <th>min_temperature_c</th>
#     <th>min_visibility_km</th>
#     <th>mean_humidity</th>
#     <th>store</th>
#     <th>max_sea_level_pressureh_pa</th>
#     <th>min_sea_level_pressureh_pa</th>
#     <th>max_wind_speed_km_h</th>
#     <th>Elapsed</th>
#     <th>competition_open_since_month</th>
#     <th>max_humidity</th>
#     <th>mean_temperature_c</th>
#     <th>mean_dew_point_c</th>
#     <th>mean_wind_speed_km_h</th>
#     <th>max_temperature_c</th>
#     <th>precipitationmm</th>
#     <th>promo2_since_week</th>
#     <th>open</th>
#     <th>mean_sea_level_pressureh_pa</th>
#     <th>min_dew_point_c</th>
#     <th>customers</th>
#     <th>target</th>
#   </tr>
#   <tr>
#     <th>a</th>
#     <th>Fog-Rain</th>
#     <th>Jan,Apr,Jul,Oct</th>
#     <th>HE</th>
#     <th>0</th>
#     <th>a</th>
#     <th>28</th>
#     <th>4</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>6</th>
#     <th>26</th>
#     <th>2013</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>0.3479</th>
#     <th>-0.6474</th>
#     <th>-0.9415</th>
#     <th>-0.3649</th>
#     <th>-0.4785</th>
#     <th>0.6155</th>
#     <th>0.5445</th>
#     <th>1.0334</th>
#     <th>0.3861</th>
#     <th>-0.0588</th>
#     <th>-0.0321</th>
#     <th>0.1734</th>
#     <th>-3.6527</th>
#     <th>-0.8994</th>
#     <th>0.5347</th>
#     <th>1.1100</th>
#     <th>0.7119</th>
#     <th>0.6076</th>
#     <th>-0.1665</th>
#     <th>0.4215</th>
#     <th>0.5771</th>
#     <th>0.9480</th>
#     <th>-0.9239</th>
#     <th>-0.9870</th>
#     <th>0.0054</th>
#     <th>0.9584</th>
#     <th>0.6350</th>
#     <th>0.6039</th>
#     <th>-0.8011</th>
#     <th>0.5391</th>
#     <th>-0.3027</th>
#     <th>-1.9906</th>
#     <th>0.0000</th>
#     <th>0.7414</th>
#     <th>0.7171</th>
#     <th>0.6990</th>
#     <th>9.080118</th>
#   </tr>
#   <tr>
#     <th>c</th>
#     <th>#na#</th>
#     <th>Mar,Jun,Sept,Dec</th>
#     <th>BY</th>
#     <th>0</th>
#     <th>c</th>
#     <th>9</th>
#     <th>0</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>12</th>
#     <th>50</th>
#     <th>2013</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>0.3479</th>
#     <th>-0.4089</th>
#     <th>-0.1023</th>
#     <th>-0.0241</th>
#     <th>-0.4785</th>
#     <th>0.6155</th>
#     <th>-0.5548</th>
#     <th>1.0334</th>
#     <th>0.1757</th>
#     <th>-0.0588</th>
#     <th>-1.1645</th>
#     <th>1.7450</th>
#     <th>0.0091</th>
#     <th>-0.8994</th>
#     <th>-0.0083</th>
#     <th>0.2330</th>
#     <th>0.0132</th>
#     <th>0.1373</th>
#     <th>0.0875</th>
#     <th>-1.4344</th>
#     <th>0.0403</th>
#     <th>-0.0241</th>
#     <th>-0.0596</th>
#     <th>-0.3491</th>
#     <th>1.4481</th>
#     <th>0.1293</th>
#     <th>0.0109</th>
#     <th>0.0471</th>
#     <th>-0.2577</th>
#     <th>0.0039</th>
#     <th>-0.3027</th>
#     <th>-0.2103</th>
#     <th>0.0000</th>
#     <th>-0.0317</th>
#     <th>-0.0256</th>
#     <th>-0.1948</th>
#     <th>8.585599</th>
#   </tr>
#   <tr>
#     <th>a</th>
#     <th>#na#</th>
#     <th>Jan,Apr,Jul,Oct</th>
#     <th>BY</th>
#     <th>0</th>
#     <th>a</th>
#     <th>6</th>
#     <th>3</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>3</th>
#     <th>10</th>
#     <th>2014</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>0.3479</th>
#     <th>-0.1911</th>
#     <th>-0.1023</th>
#     <th>-0.0241</th>
#     <th>2.0899</th>
#     <th>0.6155</th>
#     <th>-0.8645</th>
#     <th>1.0334</th>
#     <th>0.1757</th>
#     <th>-0.0588</th>
#     <th>-0.7650</th>
#     <th>-0.9191</th>
#     <th>0.0091</th>
#     <th>1.1118</th>
#     <th>-0.0083</th>
#     <th>-1.5211</th>
#     <th>0.0132</th>
#     <th>0.1373</th>
#     <th>0.0875</th>
#     <th>-1.2303</th>
#     <th>0.0403</th>
#     <th>-0.0241</th>
#     <th>-0.0596</th>
#     <th>-0.0107</th>
#     <th>-1.2269</th>
#     <th>0.1293</th>
#     <th>0.0109</th>

# %%
# Consider restricting sales forecasts to within 20% of the maximum seen
# As seen in 'y_range' in the call to tabular_learner below, we don't actually use this -
# in testing, it didn't help, in fact it sat on forecasts too much and hurt our rmspe
max_y = np.max(df.loc[:valid_idx[0], 'sales'])
y_range = torch.tensor([0, np.log(max_y*1.2)], device=defaults.device)

learn = tabular_learner(data, layers=[100,100], ps=[0.001, 0.01], emb_drop=0.01, metrics=exp_rmspe, y_range=None,
                        callback_fns=[partial(callbacks.tracker.TrackerCallback, monitor='exp_rmspe'),
                                      partial(callbacks.tracker.EarlyStoppingCallback, mode='min',
                                              monitor='exp_rmspe', min_delta=0.01, patience=1),
                                      partial(callbacks.tracker.SaveModelCallback, monitor='exp_rmspe', mode='min',
                                              every='improvement',
                                              name=datetime.now().strftime("%Y-%m-%d-%X"))])

learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.model
# Out:
# TabularModel(
#   (embeds): ModuleList(
#     (0): Embedding(4, 3)
#     (1): Embedding(23, 9)
#     (2): Embedding(5, 4)
#     (3): Embedding(9, 5)
#     (4): Embedding(5, 4)
#     (5): Embedding(5, 4)
#     (6): Embedding(32, 11)
#     (7): Embedding(8, 5)
#     (8): Embedding(3, 3)
#     (9): Embedding(3, 3)
#     (10): Embedding(3, 3)
#     (11): Embedding(3, 3)
#     (12): Embedding(3, 3)
#     (13): Embedding(3, 3)
#     (14): Embedding(13, 7)
#     (15): Embedding(53, 15)
#     (16): Embedding(4, 3)
#     (17): Embedding(3, 3)
#     (18): Embedding(3, 3)
#     (19): Embedding(3, 3)
#     (20): Embedding(3, 3)
#     (21): Embedding(3, 3)
#     (22): Embedding(3, 3)
#     (23): Embedding(3, 3)
#     (24): Embedding(3, 3)
#     (25): Embedding(3, 3)
#     (26): Embedding(3, 3)
#     (27): Embedding(3, 3)
#     (28): Embedding(3, 3)
#     (29): Embedding(3, 3)
#     (30): Embedding(3, 3)
#     (31): Embedding(3, 3)
#     (32): Embedding(3, 3)
#     (33): Embedding(3, 3)
#     (34): Embedding(3, 3)
#     (35): Embedding(3, 3)
#     (36): Embedding(3, 3)
#     (37): Embedding(3, 3)
#     (38): Embedding(3, 3)
#     (39): Embedding(3, 3)
#   )
#   (emb_drop): Dropout(p=0.01)
#   (bn_cont): BatchNorm1d(36, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layers): Sequential(
#     (0): Linear(in_features=193, out_features=100, bias=True)
#     (1): ReLU(inplace)
#     (2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.001)
#     (4): Linear(in_features=100, out_features=100, bias=True)
#     (5): ReLU(inplace)
#     (6): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.01)
#     (8): Linear(in_features=100, out_features=1, bias=True)
#   )
# )

# %%
# In previous tests I found that although the learning-rate finder above might make you want to use 1e-2,
# that's too high - it diverges all the time. Instead find the rate that you want to use, then back it 
# down by a factor of ten, so 1e-3 in this case
learn.fit_one_cycle(cyc_len=10, max_lr=1e-3)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4' class='' max='10', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       40.00% [4/10 08:50<13:15]
#     </div>
#
# <table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>exp_rmspe</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.033810</th>
#     <th>0.005616</th>
#     <th>0.070831</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.017567</th>
#     <th>0.002540</th>
#     <th>0.046082</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.014074</th>
#     <th>0.000943</th>
#     <th>0.024068</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.011717</th>
#     <th>0.002014</th>
#     <th>0.038344</th>
#   </tr>
# </table>
#
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2513' class='' max='2513', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2513/2513 00:09<00:00]
#     </div>
# Epoch 5: early stopping

# %%
# Our predictions and actuals are in log form, so get them and exp them
train_log_preds, train_log_reals = learn.get_preds(ds_type=DatasetType.Train)
train_preds = np.exp(train_log_preds).flatten()
train_reals = np.exp(train_log_reals)

# Put in dataframe for easy access
train_sub = pd.DataFrame({'Predicted': train_preds, 'Actual': train_reals})

# Prepare and show chart
fig, ax = plt.subplots()
ax.scatter(train_sub.Predicted, train_sub.Actual)
ax.plot(np.linspace(0,40000,5000), np.linspace(0,40000,5000), color='black')
ax.set_title('Forecasts on the Training set')
ax.set_xlabel('Predicted sales')
ax.set_ylabel('Actual sales')
ax.set_xticklabels(['${:,.0f}'.format(x) for x in ax.get_xticks()])
ax.set_yticklabels(['${:,.0f}'.format(x) for x in ax.get_yticks()]);

# %%
def rmspe(predicted, actual):
    return np.sqrt((((actual - predicted)/actual)**2).sum()/len(actual))

rmspe(train_sub.Predicted.values, train_sub.Actual.values)
# Out:
# 0.02653897935152917

# %%
# Our predictions and actuals are in log form, so get them and exp them
log_preds, log_reals = learn.get_preds(ds_type=DatasetType.Valid)
preds = np.exp(log_preds).flatten()
reals = np.exp(log_reals)

# Put in dataframe for easy access
sub = pd.DataFrame({'Predicted': preds, 'Actual': reals})

# Prepare and show chart
fig, ax = plt.subplots()
ax.scatter(sub.Predicted, sub.Actual)
ax.plot(np.linspace(0,40000,5000), np.linspace(0,40000,5000), color='black')
ax.set_title('Forecasts on the Validation set')
ax.set_xlabel('Predicted sales')
ax.set_ylabel('Actual sales')
ax.set_xticklabels(['${:,.0f}'.format(x) for x in ax.get_xticks()])
ax.set_yticklabels(['${:,.0f}'.format(x) for x in ax.get_yticks()]);

# %%
rmspe(sub.Predicted.values, sub.Actual.values)
# Out:
# 0.032509426510896514

# %% [markdown]
# ### Second Run, as before - no yrange or anything, just re-running

# %%
import contextlib
from datetime import datetime
from fastai import *
from fastai.tabular import *
import io
import pandas as pd
from pathlib import Path
import random

# %%
DATA_PATH = Path('../../data/interim')
path = Path('../../models/')

# %%
# Import train_valid_data and test_data dataframes
train_valid_df_raw = pd.read_csv(DATA_PATH/'train_valid_data.csv', low_memory=False)
train_valid_df = train_valid_df_raw.copy()

# Sort by date since we'll want to split by date for train/validation sets
train_valid_df.sort_values('date')

# Drop week_start and day_of_week as they'll get taken into account by add_datepart() for date
train_valid_df.drop('week_start', axis='columns', inplace=True)
train_valid_df.drop('day_of_week', axis='columns', inplace=True)

# Drop any rows where sales = 0 since we don't need to forecast those
train_valid_df = train_valid_df[train_valid_df.sales != 0]

# Run tabular.add_datepart() on both dfs to add columns about the date: ['Year', 'Month', 'Week', 'Day', 'Dayofweek',
# 'Dayofyear', 'Is_month_end', 'Is_month_start', 'Is_quarter_end', 'Is_quarter_start', 'Is_year_end', 'Is_year_start']
tabular.add_datepart(train_valid_df, 'date', drop=True, time=False)

# Category names, to which we'll apply embeddings
cat_names = ['assortment', 'events', 'promo_interval', 'state', 'state_holiday', 'store_type']

# Add the date-related categories
cat_names += ['Day', 'Dayofweek', 'Is_month_end', 'Is_month_start', 'Is_quarter_end', 'Is_quarter_start', 'Is_year_end',
              'Is_year_start', 'Month', 'Week', 'Year',]

# Continuous-variable names, which we'll make sure are all represented as floats
# Just use set difference to make sure everything is covered
cont_names = list(set(train_valid_df.columns) - set(cat_names))

# Set up transforms to 1) replace missing values for continuous variables by the median column value, 2) transform all
# categorical variables into categories, 3) normalize continuous variables.
procs = [FillMissing, Categorify, Normalize]

df = train_valid_df

# Validation set is just 80% of the whole thing
valid_idx = range(int(0.8 * len(df)), len(df))
dep_var = 'sales'

# List out the features that we don't know for predictions
unknown_in_future = ['cloud_cover', 'customers', 'dew_point_c', 'events', 'max_gust_speed_km_h', 'max_humidity',
                     'max_sea_level_pressureh_pa', 'max_temperature_c', 'max_visibility_km', 'max_wind_speed_km_h',
                     'mean_dew_point_c', 'mean_humidity', 'mean_sea_level_pressureh_pa', 'mean_temperature_c', 
                     'mean_visibility_km', 'mean_wind_speed_km_h', 'min_dew_point_c',  'min_humidity',
                     'min_sea_level_pressureh_pa', 'min_temperature_c', 'min_visibility_km', 'precipitationmm', 'trend',
                     'wind_dir_degrees']

# List of features that we know for predictions
known_in_future = set(train_valid_df.columns) - set(unknown_in_future)

print('Known: ', sorted(known_in_future), '\n')

# Make sure that features we don't know for predictions are all marked as NA in the validation set
# Our FillMissing pre-processing will account for these
train_valid_df.loc[valid_idx[0]:valid_idx[-1], unknown_in_future] = np.NaN

data = (TabularList.from_df(df, path=path, cat_names=cat_names, cont_names=cont_names, procs=procs)
                   .split_by_idx(valid_idx)
                   .label_from_df(cols=dep_var, label_cls=FloatList, log=True)
                   .databunch())

data.show_batch()
# Out:
# Known:  ['Day', 'Dayofweek', 'Dayofyear', 'Elapsed', 'Is_month_end', 'Is_month_start', 'Is_quarter_end', 'Is_quarter_start', 'Is_year_end', 'Is_year_start', 'Month', 'Week', 'Year', 'assortment', 'competition_distance', 'competition_open_since_month', 'competition_open_since_year', 'open', 'promo', 'promo2', 'promo2_since_week', 'promo2_since_year', 'promo_interval', 'sales', 'school_holiday', 'state', 'state_holiday', 'store', 'store_type']
# <table>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <tr>
#     <th>assortment</th>
#     <th>events</th>
#     <th>promo_interval</th>
#     <th>state</th>
#     <th>state_holiday</th>
#     <th>store_type</th>
#     <th>Day</th>
#     <th>Dayofweek</th>
#     <th>Is_month_end</th>
#     <th>Is_month_start</th>
#     <th>Is_quarter_end</th>
#     <th>Is_quarter_start</th>
#     <th>Is_year_end</th>
#     <th>Is_year_start</th>
#     <th>Month</th>
#     <th>Week</th>
#     <th>Year</th>
#     <th>precipitationmm_na</th>
#     <th>wind_dir_degrees_na</th>
#     <th>min_temperature_c_na</th>
#     <th>mean_wind_speed_km_h_na</th>
#     <th>max_visibility_km_na</th>
#     <th>cloud_cover_na</th>
#     <th>max_gust_speed_km_h_na</th>
#     <th>max_humidity_na</th>
#     <th>max_sea_level_pressureh_pa_na</th>
#     <th>trend_na</th>
#     <th>max_temperature_c_na</th>
#     <th>mean_temperature_c_na</th>
#     <th>mean_visibility_km_na</th>
#     <th>customers_na</th>
#     <th>mean_sea_level_pressureh_pa_na</th>
#     <th>min_humidity_na</th>
#     <th>dew_point_c_na</th>
#     <th>max_wind_speed_km_h_na</th>
#     <th>mean_humidity_na</th>
#     <th>min_dew_point_c_na</th>
#     <th>min_visibility_km_na</th>
#     <th>min_sea_level_pressureh_pa_na</th>
#     <th>mean_dew_point_c_na</th>
#     <th>precipitationmm</th>
#     <th>wind_dir_degrees</th>
#     <th>min_temperature_c</th>
#     <th>mean_wind_speed_km_h</th>
#     <th>max_visibility_km</th>
#     <th>cloud_cover</th>
#     <th>Dayofyear</th>
#     <th>max_gust_speed_km_h</th>
#     <th>max_humidity</th>
#     <th>competition_distance</th>
#     <th>Elapsed</th>
#     <th>promo2</th>
#     <th>max_sea_level_pressureh_pa</th>
#     <th>trend</th>
#     <th>competition_open_since_year</th>
#     <th>max_temperature_c</th>
#     <th>school_holiday</th>
#     <th>promo</th>
#     <th>mean_temperature_c</th>
#     <th>store</th>
#     <th>mean_visibility_km</th>
#     <th>sales</th>
#     <th>customers</th>
#     <th>competition_open_since_month</th>
#     <th>mean_sea_level_pressureh_pa</th>
#     <th>min_humidity</th>
#     <th>dew_point_c</th>
#     <th>max_wind_speed_km_h</th>
#     <th>mean_humidity</th>
#     <th>open</th>
#     <th>promo2_since_year</th>
#     <th>min_dew_point_c</th>
#     <th>min_visibility_km</th>
#     <th>min_sea_level_pressureh_pa</th>
#     <th>mean_dew_point_c</th>
#     <th>promo2_since_week</th>
#     <th>target</th>
#   </tr>
#   <tr>
#     <th>a</th>
#     <th>Rain</th>
#     <th>None</th>
#     <th>BE</th>
#     <th>0</th>
#     <th>a</th>
#     <th>30</th>
#     <th>3</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>10</th>
#     <th>44</th>
#     <th>2014</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>-0.3027</th>
#     <th>0.3745</th>
#     <th>0.1879</th>
#     <th>-1.3446</th>
#     <th>-1.9436</th>
#     <th>1.0362</th>
#     <th>1.3616</th>
#     <th>0.0091</th>
#     <th>-0.0089</th>
#     <th>-0.5958</th>
#     <th>0.9150</th>
#     <th>-0.9677</th>
#     <th>1.1138</th>
#     <th>0.0026</th>
#     <th>-0.7650</th>
#     <th>-0.3975</th>
#     <th>2.0899</th>
#     <th>-0.8994</th>
#     <th>-0.1451</th>
#     <th>-0.0517</th>
#     <th>-1.7135</th>
#     <th>1.7722</th>
#     <th>2.2041</th>
#     <th>-2.3733</th>
#     <th>1.1279</th>
#     <th>1.3957</th>
#     <th>-0.0083</th>
#     <th>-1.6648</th>
#     <th>1.0187</th>
#     <th>0.0000</th>
#     <th>0.0256</th>
#     <th>0.3458</th>
#     <th>-1.2738</th>
#     <th>0.9480</th>
#     <th>0.2327</th>
#     <th>-0.0432</th>
#     <th>9.44177</th>
#   </tr>
#   <tr>
#     <th>c</th>
#     <th>Rain</th>
#     <th>Feb,May,Aug,Nov</th>
#     <th>NW</th>
#     <th>0</th>
#     <th>c</th>
#     <th>29</th>
#     <th>4</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>11</th>
#     <th>48</th>
#     <th>2013</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>1.8214</th>
#     <th>0.7135</th>
#     <th>-0.3361</th>
#     <th>0.1046</th>
#     <th>0.6155</th>
#     <th>1.0362</th>
#     <th>1.6491</th>
#     <th>-0.3031</th>
#     <th>-0.0089</th>
#     <th>-0.6281</th>
#     <th>-0.3880</th>
#     <th>1.0334</th>
#     <th>1.7847</th>
#     <th>0.0026</th>
#     <th>-0.1657</th>
#     <th>-0.7989</th>
#     <th>-0.4785</th>
#     <th>-0.8994</th>
#     <th>-0.6131</th>
#     <th>1.6774</th>
#     <th>-0.2952</th>
#     <th>-0.8023</th>
#     <th>-0.7735</th>
#     <th>1.4481</th>
#     <th>0.8702</th>
#     <th>1.2821</th>
#     <th>-0.3704</th>
#     <th>0.6812</th>
#     <th>0.7648</th>
#     <th>0.0000</th>
#     <th>1.1100</th>
#     <th>-0.2112</th>
#     <th>-1.0386</th>
#     <th>0.2190</th>
#     <th>-0.3240</th>
#     <th>-1.9906</th>
#     <th>8.430109</th>
#   </tr>
#   <tr>
#     <th>c</th>
#     <th>Fog-Rain</th>
#     <th>Mar,Jun,Sept,Dec</th>
#     <th>SH</th>
#     <th>0</th>
#     <th>a</th>
#     <th>22</th>
#     <th>5</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>11</th>
#     <th>47</th>
#     <th>2014</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>0.5461</th>
#     <th>-0.6893</th>
#     <th>-1.2094</th>
#     <th>-0.4388</th>
#     <th>-2.0716</th>
#     <th>1.0362</th>
#     <th>1.5820</th>
#     <th>0.0091</th>
#     <th>0.9584</th>
#     <th>-0.3780</th>
#     <th>1.0044</th>
#     <th>1.0334</th>
#     <th>0.9796</th>
#     <th>-0.1023</th>
#     <th>-0.0321</th>
#     <th>-1.0665</th>
#     <th>-0.4785</th>
#     <th>-0.8994</th>
#     <th>-1.0812</th>
#     <th>0.0441</th>
#     <th>-1.2407</th>
#     <th>-1.0167</th>
#     <th>-0.9310</th>
#     <th>0.0054</th>
#     <th>0.9990</th>

# %%
# Consider restricting sales forecasts to within 20% of the maximum seen
# As seen in 'y_range' in the call to tabular_learner below, we don't actually use this -
# in testing, it didn't help, in fact it sat on forecasts too much and hurt our rmspe
max_y = np.max(df.loc[:valid_idx[0], 'sales'])
y_range = torch.tensor([0, np.log(max_y*1.2)], device=defaults.device)

learn = tabular_learner(data, layers=[100,100], ps=[0.001, 0.01], emb_drop=0.01, metrics=exp_rmspe, y_range=None,
                        callback_fns=[partial(callbacks.tracker.TrackerCallback, monitor='exp_rmspe'),
                                      partial(callbacks.tracker.EarlyStoppingCallback, mode='min',
                                              monitor='exp_rmspe', min_delta=0.01, patience=1),
                                      partial(callbacks.tracker.SaveModelCallback, monitor='exp_rmspe', mode='min',
                                              every='improvement',
                                              name=datetime.now().strftime("%Y-%m-%d-%X"))])

learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
# In previous tests I found that although the learning-rate finder above might make you want to use 1e-2,
# that's too high - it diverges all the time. Instead find the rate that you want to use, then back it 
# down by a factor of ten, so 1e-3 in this case
learn.fit_one_cycle(cyc_len=10, max_lr=1e-3)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4' class='' max='10', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       40.00% [4/10 08:47<13:11]
#     </div>
#
# <table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>exp_rmspe</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.039231</th>
#     <th>0.007214</th>
#     <th>0.081690</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.017912</th>
#     <th>0.003150</th>
#     <th>0.055433</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.013847</th>
#     <th>0.001479</th>
#     <th>0.034123</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.013114</th>
#     <th>0.005830</th>
#     <th>0.063707</th>
#   </tr>
# </table>
#
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2513' class='' max='2513', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2513/2513 00:08<00:00]
#     </div>
# Epoch 5: early stopping

# %%
# Our predictions and actuals are in log form, so get them and exp them
train_log_preds, train_log_reals = learn.get_preds(ds_type=DatasetType.Train)
train_preds = np.exp(train_log_preds).flatten()
train_reals = np.exp(train_log_reals)

# Put in dataframe for easy access
train_sub = pd.DataFrame({'Predicted': train_preds, 'Actual': train_reals})

# Prepare and show chart
fig, ax = plt.subplots()
ax.scatter(train_sub.Predicted, train_sub.Actual)
ax.plot(np.linspace(0,40000,5000), np.linspace(0,40000,5000), color='black')
ax.set_title('Forecasts on the Training set')
ax.set_xlabel('Predicted sales')
ax.set_ylabel('Actual sales')
ax.set_xticklabels(['${:,.0f}'.format(x) for x in ax.get_xticks()])
ax.set_yticklabels(['${:,.0f}'.format(x) for x in ax.get_yticks()]);

# %%
def rmspe(predicted, actual):
    return np.sqrt((((actual - predicted)/actual)**2).sum()/len(actual))

rmspe(train_sub.Predicted.values, train_sub.Actual.values)
# Out:
# 0.03730641337931875

# %%
# Our predictions and actuals are in log form, so get them and exp them
log_preds, log_reals = learn.get_preds(ds_type=DatasetType.Valid)
preds = np.exp(log_preds).flatten()
reals = np.exp(log_reals)

# Put in dataframe for easy access
sub = pd.DataFrame({'Predicted': preds, 'Actual': reals})

# Prepare and show chart
fig, ax = plt.subplots()
ax.scatter(sub.Predicted, sub.Actual)
ax.plot(np.linspace(0,40000,5000), np.linspace(0,40000,5000), color='black')
ax.set_title('Forecasts on the Validation set')
ax.set_xlabel('Predicted sales')
ax.set_ylabel('Actual sales')
ax.set_xticklabels(['${:,.0f}'.format(x) for x in ax.get_xticks()])
ax.set_yticklabels(['${:,.0f}'.format(x) for x in ax.get_yticks()]);

# %%
rmspe(sub.Predicted.values, sub.Actual.values)
# Out:
# 0.04145955422400725

# %% [markdown]
# ### Third run, trying with y_range

# %%
# Import train_valid_data and test_data dataframes
train_valid_df_raw = pd.read_csv(DATA_PATH/'train_valid_data.csv', low_memory=False)
train_valid_df = train_valid_df_raw.copy()

# Sort by date since we'll want to split by date for train/validation sets
train_valid_df.sort_values('date')

# Drop week_start and day_of_week as they'll get taken into account by add_datepart() for date
train_valid_df.drop('week_start', axis='columns', inplace=True)
train_valid_df.drop('day_of_week', axis='columns', inplace=True)

# Drop any rows where sales = 0 since we don't need to forecast those
train_valid_df = train_valid_df[train_valid_df.sales != 0]

# Run tabular.add_datepart() on both dfs to add columns about the date: ['Year', 'Month', 'Week', 'Day', 'Dayofweek',
# 'Dayofyear', 'Is_month_end', 'Is_month_start', 'Is_quarter_end', 'Is_quarter_start', 'Is_year_end', 'Is_year_start']
tabular.add_datepart(train_valid_df, 'date', drop=True, time=False)

# Category names, to which we'll apply embeddings
cat_names = ['assortment', 'events', 'promo_interval', 'state', 'state_holiday', 'store_type']

# Add the date-related categories
cat_names += ['Day', 'Dayofweek', 'Is_month_end', 'Is_month_start', 'Is_quarter_end', 'Is_quarter_start', 'Is_year_end',
              'Is_year_start', 'Month', 'Week', 'Year',]

# Continuous-variable names, which we'll make sure are all represented as floats
# Just use set difference to make sure everything is covered
cont_names = list(set(train_valid_df.columns) - set(cat_names))

# Set up transforms to 1) replace missing values for continuous variables by the median column value, 2) transform all
# categorical variables into categories, 3) normalize continuous variables.
procs = [FillMissing, Categorify, Normalize]

df = train_valid_df

# Validation set is just 80% of the whole thing
valid_idx = range(int(0.8 * len(df)), len(df))
dep_var = 'sales'

# List out the features that we don't know for predictions
unknown_in_future = ['cloud_cover', 'customers', 'dew_point_c', 'events', 'max_gust_speed_km_h', 'max_humidity',
                     'max_sea_level_pressureh_pa', 'max_temperature_c', 'max_visibility_km', 'max_wind_speed_km_h',
                     'mean_dew_point_c', 'mean_humidity', 'mean_sea_level_pressureh_pa', 'mean_temperature_c', 
                     'mean_visibility_km', 'mean_wind_speed_km_h', 'min_dew_point_c',  'min_humidity',
                     'min_sea_level_pressureh_pa', 'min_temperature_c', 'min_visibility_km', 'precipitationmm', 'trend',
                     'wind_dir_degrees']

# List of features that we know for predictions
known_in_future = set(train_valid_df.columns) - set(unknown_in_future)

print('Known: ', sorted(known_in_future), '\n')

# Make sure that features we don't know for predictions are all marked as NA in the validation set
# Our FillMissing pre-processing will account for these
train_valid_df.loc[valid_idx[0]:valid_idx[-1], unknown_in_future] = np.NaN

data = (TabularList.from_df(df, path=path, cat_names=cat_names, cont_names=cont_names, procs=procs)
                   .split_by_idx(valid_idx)
                   .label_from_df(cols=dep_var, label_cls=FloatList, log=True)
                   .databunch())

data.show_batch()
# Out:
# Known:  ['Day', 'Dayofweek', 'Dayofyear', 'Elapsed', 'Is_month_end', 'Is_month_start', 'Is_quarter_end', 'Is_quarter_start', 'Is_year_end', 'Is_year_start', 'Month', 'Week', 'Year', 'assortment', 'competition_distance', 'competition_open_since_month', 'competition_open_since_year', 'open', 'promo', 'promo2', 'promo2_since_week', 'promo2_since_year', 'promo_interval', 'sales', 'school_holiday', 'state', 'state_holiday', 'store', 'store_type']
# <table>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <tr>
#     <th>assortment</th>
#     <th>events</th>
#     <th>promo_interval</th>
#     <th>state</th>
#     <th>state_holiday</th>
#     <th>store_type</th>
#     <th>Day</th>
#     <th>Dayofweek</th>
#     <th>Is_month_end</th>
#     <th>Is_month_start</th>
#     <th>Is_quarter_end</th>
#     <th>Is_quarter_start</th>
#     <th>Is_year_end</th>
#     <th>Is_year_start</th>
#     <th>Month</th>
#     <th>Week</th>
#     <th>Year</th>
#     <th>precipitationmm_na</th>
#     <th>wind_dir_degrees_na</th>
#     <th>min_temperature_c_na</th>
#     <th>mean_wind_speed_km_h_na</th>
#     <th>max_visibility_km_na</th>
#     <th>cloud_cover_na</th>
#     <th>max_gust_speed_km_h_na</th>
#     <th>max_humidity_na</th>
#     <th>max_sea_level_pressureh_pa_na</th>
#     <th>trend_na</th>
#     <th>max_temperature_c_na</th>
#     <th>mean_temperature_c_na</th>
#     <th>mean_visibility_km_na</th>
#     <th>customers_na</th>
#     <th>mean_sea_level_pressureh_pa_na</th>
#     <th>min_humidity_na</th>
#     <th>dew_point_c_na</th>
#     <th>max_wind_speed_km_h_na</th>
#     <th>mean_humidity_na</th>
#     <th>min_dew_point_c_na</th>
#     <th>min_visibility_km_na</th>
#     <th>min_sea_level_pressureh_pa_na</th>
#     <th>mean_dew_point_c_na</th>
#     <th>precipitationmm</th>
#     <th>wind_dir_degrees</th>
#     <th>min_temperature_c</th>
#     <th>mean_wind_speed_km_h</th>
#     <th>max_visibility_km</th>
#     <th>cloud_cover</th>
#     <th>Dayofyear</th>
#     <th>max_gust_speed_km_h</th>
#     <th>max_humidity</th>
#     <th>competition_distance</th>
#     <th>Elapsed</th>
#     <th>promo2</th>
#     <th>max_sea_level_pressureh_pa</th>
#     <th>trend</th>
#     <th>competition_open_since_year</th>
#     <th>max_temperature_c</th>
#     <th>school_holiday</th>
#     <th>promo</th>
#     <th>mean_temperature_c</th>
#     <th>store</th>
#     <th>mean_visibility_km</th>
#     <th>sales</th>
#     <th>customers</th>
#     <th>competition_open_since_month</th>
#     <th>mean_sea_level_pressureh_pa</th>
#     <th>min_humidity</th>
#     <th>dew_point_c</th>
#     <th>max_wind_speed_km_h</th>
#     <th>mean_humidity</th>
#     <th>open</th>
#     <th>promo2_since_year</th>
#     <th>min_dew_point_c</th>
#     <th>min_visibility_km</th>
#     <th>min_sea_level_pressureh_pa</th>
#     <th>mean_dew_point_c</th>
#     <th>promo2_since_week</th>
#     <th>target</th>
#   </tr>
#   <tr>
#     <th>a</th>
#     <th>Rain</th>
#     <th>None</th>
#     <th>BE</th>
#     <th>0</th>
#     <th>c</th>
#     <th>21</th>
#     <th>1</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>10</th>
#     <th>43</th>
#     <th>2014</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>-0.3027</th>
#     <th>0.3978</th>
#     <th>0.8865</th>
#     <th>0.2858</th>
#     <th>0.6155</th>
#     <th>0.3479</th>
#     <th>1.2754</th>
#     <th>0.0091</th>
#     <th>0.1293</th>
#     <th>-0.4154</th>
#     <th>0.8800</th>
#     <th>-0.9677</th>
#     <th>-1.0331</th>
#     <th>0.9466</th>
#     <th>0.0341</th>
#     <th>0.2715</th>
#     <th>2.0899</th>
#     <th>1.1118</th>
#     <th>0.4789</th>
#     <th>1.5227</th>
#     <th>0.4140</th>
#     <th>0.4995</th>
#     <th>0.6855</th>
#     <th>-1.2269</th>
#     <th>-1.3202</th>
#     <th>0.3166</th>
#     <th>0.5347</th>
#     <th>-0.0596</th>
#     <th>0.3415</th>
#     <th>0.0000</th>
#     <th>0.0256</th>
#     <th>0.9028</th>
#     <th>0.6076</th>
#     <th>-1.8467</th>
#     <th>0.6039</th>
#     <th>-0.0432</th>
#     <th>9.064042</th>
#   </tr>
#   <tr>
#     <th>a</th>
#     <th>Rain</th>
#     <th>Jan,Apr,Jul,Oct</th>
#     <th>HE</th>
#     <th>0</th>
#     <th>a</th>
#     <th>5</th>
#     <th>2</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>2</th>
#     <th>6</th>
#     <th>2014</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>0.9726</th>
#     <th>-1.0868</th>
#     <th>-1.2094</th>
#     <th>-0.4388</th>
#     <th>-1.6877</th>
#     <th>0.3479</th>
#     <th>-1.1970</th>
#     <th>0.0091</th>
#     <th>0.9584</th>
#     <th>-0.4154</th>
#     <th>-0.1235</th>
#     <th>1.0334</th>
#     <th>-1.4357</th>
#     <th>0.5270</th>
#     <th>0.2338</th>
#     <th>-1.2003</th>
#     <th>-0.4785</th>
#     <th>1.1118</th>
#     <th>-1.2372</th>
#     <th>1.0680</th>
#     <th>-1.0043</th>
#     <th>-0.5583</th>
#     <th>-1.0044</th>
#     <th>-0.0804</th>
#     <th>-1.5779</th>
#     <th>1.6229</th>
#     <th>-0.7324</th>
#     <th>-0.5535</th>
#     <th>1.7806</th>
#     <th>0.0000</th>
#     <th>-2.3981</th>
#     <th>-0.7683</th>
#     <th>-0.5683</th>
#     <th>-1.4822</th>
#     <th>-0.6952</th>
#     <th>1.3606</th>
#     <th>8.583543</th>
#   </tr>
#   <tr>
#     <th>a</th>
#     <th>Fog-Rain</th>
#     <th>None</th>
#     <th>NW</th>
#     <th>0</th>
#     <th>a</th>
#     <th>17</th>
#     <th>0</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>11</th>
#     <th>47</th>
#     <th>2014</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>-0.3027</th>
#     <th>-0.7478</th>
#     <th>0.3626</th>
#     <th>0.6481</th>
#     <th>-0.0242</th>
#     <th>0.3479</th>
#     <th>1.5341</th>
#     <th>0.0091</th>
#     <th>-0.0089</th>
#     <th>-0.5868</th>
#     <th>0.9850</th>
#     <th>-0.9677</th>
#     <th>-1.4357</th>
#     <th>0.5270</th>
#     <th>-0.5652</th>
#     <th>-0.2637</th>
#     <th>-0.4785</th>
#     <th>-0.8994</th>
#     <th>0.0109</th>
#     <th>0.5824</th>
#     <th>-0.0588</th>
#     <th>-0.9416</th>
#     <th>-0.5724</th>
#     <th>1.0660</th>
#     <th>-1.4490</th>
#     <th>0.5438</

# %%
# Consider restricting sales forecasts to within 20% of the maximum seen
# As seen in 'y_range' in the call to tabular_learner below, we don't actually use this -
# in testing, it didn't help, in fact it sat on forecasts too much and hurt our rmspe
max_y = np.max(df.loc[:valid_idx[0], 'sales'])
y_range = torch.tensor([0, np.log(max_y*1.2)], device=defaults.device)

learn = tabular_learner(data, layers=[100,100], ps=[0.001, 0.01], emb_drop=0.01, metrics=exp_rmspe, y_range=y_range,
                        callback_fns=[partial(callbacks.tracker.TrackerCallback, monitor='exp_rmspe'),
                                      partial(callbacks.tracker.EarlyStoppingCallback, mode='min',
                                              monitor='exp_rmspe', min_delta=0.01, patience=1),
                                      partial(callbacks.tracker.SaveModelCallback, monitor='exp_rmspe', mode='min',
                                              every='improvement',
                                              name=datetime.now().strftime("%Y-%m-%d-%X"))])

learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
# In previous tests I found that although the learning-rate finder above might make you want to use 1e-2,
# that's too high - it diverges all the time. Instead find the rate that you want to use, then back it 
# down by a factor of ten, so 1e-3 in this case
learn.fit_one_cycle(cyc_len=10, max_lr=1e-3)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3' class='' max='10', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       30.00% [3/10 06:40<15:35]
#     </div>
#
# <table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>exp_rmspe</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.010973</th>
#     <th>0.002618</th>
#     <th>0.048322</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.006265</th>
#     <th>0.001376</th>
#     <th>0.034167</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.006586</th>
#     <th>0.001869</th>
#     <th>0.040421</th>
#   </tr>
# </table>
#
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2513' class='' max='2513', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2513/2513 00:09<00:00]
#     </div>
# Epoch 4: early stopping

# %%
# Our predictions and actuals are in log form, so get them and exp them
train_log_preds, train_log_reals = learn.get_preds(ds_type=DatasetType.Train)
train_preds = np.exp(train_log_preds).flatten()
train_reals = np.exp(train_log_reals)

# Put in dataframe for easy access
train_sub = pd.DataFrame({'Predicted': train_preds, 'Actual': train_reals})

# Prepare and show chart
fig, ax = plt.subplots()
ax.scatter(train_sub.Predicted, train_sub.Actual)
ax.plot(np.linspace(0,40000,5000), np.linspace(0,40000,5000), color='black')
ax.set_title('Forecasts on the Training set')
ax.set_xlabel('Predicted sales')
ax.set_ylabel('Actual sales')
ax.set_xticklabels(['${:,.0f}'.format(x) for x in ax.get_xticks()])
ax.set_yticklabels(['${:,.0f}'.format(x) for x in ax.get_yticks()]);

# %%
def rmspe(predicted, actual):
    return np.sqrt((((actual - predicted)/actual)**2).sum()/len(actual))

rmspe(train_sub.Predicted.values, train_sub.Actual.values)
# Out:
# 0.03583682061699547

# %%
# Our predictions and actuals are in log form, so get them and exp them
log_preds, log_reals = learn.get_preds(ds_type=DatasetType.Valid)
preds = np.exp(log_preds).flatten()
reals = np.exp(log_reals)

# Put in dataframe for easy access
sub = pd.DataFrame({'Predicted': preds, 'Actual': reals})

# Prepare and show chart
fig, ax = plt.subplots()
ax.scatter(sub.Predicted, sub.Actual)
ax.plot(np.linspace(0,40000,5000), np.linspace(0,40000,5000), color='black')
ax.set_title('Forecasts on the Validation set')
ax.set_xlabel('Predicted sales')
ax.set_ylabel('Actual sales')
ax.set_xticklabels(['${:,.0f}'.format(x) for x in ax.get_xticks()])
ax.set_yticklabels(['${:,.0f}'.format(x) for x in ax.get_yticks()]);

# %%
rmspe(sub.Predicted.values, sub.Actual.values)
# Out:
# 0.039451198380915056

# %% [markdown]
# ### Fourth run, trying with Stores as category (embedded)

# %%
# Import train_valid_data and test_data dataframes
train_valid_df_raw = pd.read_csv(DATA_PATH/'train_valid_data.csv', low_memory=False)
train_valid_df = train_valid_df_raw.copy()

# Sort by date since we'll want to split by date for train/validation sets
train_valid_df.sort_values('date')

# Drop week_start and day_of_week as they'll get taken into account by add_datepart() for date
train_valid_df.drop('week_start', axis='columns', inplace=True)
train_valid_df.drop('day_of_week', axis='columns', inplace=True)

# Drop any rows where sales = 0 since we don't need to forecast those
train_valid_df = train_valid_df[train_valid_df.sales != 0]

# Run tabular.add_datepart() on both dfs to add columns about the date: ['Year', 'Month', 'Week', 'Day', 'Dayofweek',
# 'Dayofyear', 'Is_month_end', 'Is_month_start', 'Is_quarter_end', 'Is_quarter_start', 'Is_year_end', 'Is_year_start']
tabular.add_datepart(train_valid_df, 'date', drop=True, time=False)

# Category names, to which we'll apply embeddings
cat_names = ['assortment', 'events', 'promo_interval', 'state', 'state_holiday', 'store', 'store_type']

# Add the date-related categories
cat_names += ['Day', 'Dayofweek', 'Is_month_end', 'Is_month_start', 'Is_quarter_end', 'Is_quarter_start', 'Is_year_end',
              'Is_year_start', 'Month', 'Week', 'Year',]

# Continuous-variable names, which we'll make sure are all represented as floats
# Just use set difference to make sure everything is covered
cont_names = list(set(train_valid_df.columns) - set(cat_names))

# Set up transforms to 1) replace missing values for continuous variables by the median column value, 2) transform all
# categorical variables into categories, 3) normalize continuous variables.
procs = [FillMissing, Categorify, Normalize]

df = train_valid_df

# Validation set is just 80% of the whole thing
valid_idx = range(int(0.8 * len(df)), len(df))
dep_var = 'sales'

# List out the features that we don't know for predictions
unknown_in_future = ['cloud_cover', 'customers', 'dew_point_c', 'events', 'max_gust_speed_km_h', 'max_humidity',
                     'max_sea_level_pressureh_pa', 'max_temperature_c', 'max_visibility_km', 'max_wind_speed_km_h',
                     'mean_dew_point_c', 'mean_humidity', 'mean_sea_level_pressureh_pa', 'mean_temperature_c', 
                     'mean_visibility_km', 'mean_wind_speed_km_h', 'min_dew_point_c',  'min_humidity',
                     'min_sea_level_pressureh_pa', 'min_temperature_c', 'min_visibility_km', 'precipitationmm', 'trend',
                     'wind_dir_degrees']

# List of features that we know for predictions
known_in_future = set(train_valid_df.columns) - set(unknown_in_future)

print('Known: ', sorted(known_in_future), '\n')

# Make sure that features we don't know for predictions are all marked as NA in the validation set
# Our FillMissing pre-processing will account for these
train_valid_df.loc[valid_idx[0]:valid_idx[-1], unknown_in_future] = np.NaN

data = (TabularList.from_df(df, path=path, cat_names=cat_names, cont_names=cont_names, procs=procs)
                   .split_by_idx(valid_idx)
                   .label_from_df(cols=dep_var, label_cls=FloatList, log=True)
                   .databunch())

data.show_batch()
# Out:
# Known:  ['Day', 'Dayofweek', 'Dayofyear', 'Elapsed', 'Is_month_end', 'Is_month_start', 'Is_quarter_end', 'Is_quarter_start', 'Is_year_end', 'Is_year_start', 'Month', 'Week', 'Year', 'assortment', 'competition_distance', 'competition_open_since_month', 'competition_open_since_year', 'open', 'promo', 'promo2', 'promo2_since_week', 'promo2_since_year', 'promo_interval', 'sales', 'school_holiday', 'state', 'state_holiday', 'store', 'store_type']
# <table>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <tr>
#     <th>assortment</th>
#     <th>events</th>
#     <th>promo_interval</th>
#     <th>state</th>
#     <th>state_holiday</th>
#     <th>store</th>
#     <th>store_type</th>
#     <th>Day</th>
#     <th>Dayofweek</th>
#     <th>Is_month_end</th>
#     <th>Is_month_start</th>
#     <th>Is_quarter_end</th>
#     <th>Is_quarter_start</th>
#     <th>Is_year_end</th>
#     <th>Is_year_start</th>
#     <th>Month</th>
#     <th>Week</th>
#     <th>Year</th>
#     <th>precipitationmm_na</th>
#     <th>wind_dir_degrees_na</th>
#     <th>min_temperature_c_na</th>
#     <th>mean_wind_speed_km_h_na</th>
#     <th>max_visibility_km_na</th>
#     <th>cloud_cover_na</th>
#     <th>max_gust_speed_km_h_na</th>
#     <th>max_humidity_na</th>
#     <th>max_sea_level_pressureh_pa_na</th>
#     <th>trend_na</th>
#     <th>max_temperature_c_na</th>
#     <th>mean_temperature_c_na</th>
#     <th>mean_visibility_km_na</th>
#     <th>customers_na</th>
#     <th>mean_sea_level_pressureh_pa_na</th>
#     <th>min_humidity_na</th>
#     <th>dew_point_c_na</th>
#     <th>max_wind_speed_km_h_na</th>
#     <th>mean_humidity_na</th>
#     <th>min_dew_point_c_na</th>
#     <th>min_visibility_km_na</th>
#     <th>min_sea_level_pressureh_pa_na</th>
#     <th>mean_dew_point_c_na</th>
#     <th>precipitationmm</th>
#     <th>wind_dir_degrees</th>
#     <th>min_temperature_c</th>
#     <th>mean_wind_speed_km_h</th>
#     <th>max_visibility_km</th>
#     <th>cloud_cover</th>
#     <th>Dayofyear</th>
#     <th>max_gust_speed_km_h</th>
#     <th>max_humidity</th>
#     <th>competition_distance</th>
#     <th>Elapsed</th>
#     <th>promo2</th>
#     <th>max_sea_level_pressureh_pa</th>
#     <th>trend</th>
#     <th>competition_open_since_year</th>
#     <th>max_temperature_c</th>
#     <th>school_holiday</th>
#     <th>promo</th>
#     <th>mean_temperature_c</th>
#     <th>mean_visibility_km</th>
#     <th>sales</th>
#     <th>customers</th>
#     <th>competition_open_since_month</th>
#     <th>mean_sea_level_pressureh_pa</th>
#     <th>min_humidity</th>
#     <th>dew_point_c</th>
#     <th>max_wind_speed_km_h</th>
#     <th>mean_humidity</th>
#     <th>open</th>
#     <th>promo2_since_year</th>
#     <th>min_dew_point_c</th>
#     <th>min_visibility_km</th>
#     <th>min_sea_level_pressureh_pa</th>
#     <th>mean_dew_point_c</th>
#     <th>promo2_since_week</th>
#     <th>target</th>
#   </tr>
#   <tr>
#     <th>b</th>
#     <th>Fog</th>
#     <th>Jan,Apr,Jul,Oct</th>
#     <th>NW</th>
#     <th>0</th>
#     <th>769</th>
#     <th>b</th>
#     <th>17</th>
#     <th>6</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>5</th>
#     <th>20</th>
#     <th>2015</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>-0.3027</th>
#     <th>0.6550</th>
#     <th>-0.3361</th>
#     <th>-1.1634</th>
#     <th>0.6155</th>
#     <th>-0.3403</th>
#     <th>-0.2291</th>
#     <th>0.0091</th>
#     <th>0.9584</th>
#     <th>-0.5623</th>
#     <th>1.6890</th>
#     <th>1.0334</th>
#     <th>1.1138</th>
#     <th>1.4711</th>
#     <th>-0.0321</th>
#     <th>0.5391</th>
#     <th>-0.4785</th>
#     <th>-0.8994</th>
#     <th>0.1669</th>
#     <th>0.6504</th>
#     <th>1.3639</th>
#     <th>5.8745</th>
#     <th>0.0054</th>
#     <th>1.1279</th>
#     <th>-1.1600</th>
#     <th>-0.0083</th>
#     <th>-0.9239</th>
#     <th>-0.5898</th>
#     <th>0.0000</th>
#     <th>0.2330</th>
#     <th>-0.0256</th>
#     <th>0.6076</th>
#     <th>0.9480</th>
#     <th>0.0471</th>
#     <th>2.5126</th>
#     <th>9.335386</th>
#   </tr>
#   <tr>
#     <th>c</th>
#     <th>Rain</th>
#     <th>Mar,Jun,Sept,Dec</th>
#     <th>TH</th>
#     <th>0</th>
#     <th>838</th>
#     <th>d</th>
#     <th>21</th>
#     <th>4</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>6</th>
#     <th>25</th>
#     <th>2013</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>-0.3027</th>
#     <th>0.4563</th>
#     <th>1.5852</th>
#     <th>1.5539</th>
#     <th>-0.0242</th>
#     <th>-1.0286</th>
#     <th>0.1063</th>
#     <th>0.0091</th>
#     <th>0.1293</th>
#     <th>0.2176</th>
#     <th>-1.0142</th>
#     <th>1.0334</th>
#     <th>-0.2280</th>
#     <th>-0.3121</th>
#     <th>-0.0321</th>
#     <th>1.0742</th>
#     <th>-0.4785</th>
#     <th>1.1118</th>
#     <th>1.4150</th>
#     <th>-0.5315</th>
#     <th>0.4607</th>
#     <th>0.3051</th>
#     <th>0.0054</th>
#     <th>-0.2894</th>
#     <th>-0.5353</th>
#     <th>1.6209</th>
#     <th>1.4221</th>
#     <th>-0.5051</th>
#     <th>0.0000</th>
#     <th>-0.6440</th>
#     <th>1.2742</th>
#     <th>0.6076</th>
#     <th>-0.3886</th>
#     <th>1.3462</th>
#     <th>2.5126</th>
#     <th>9.049937</th>
#   </tr>
#   <tr>
#     <th>c</th>
#     <th>Rain</th>
#     <th>Jan,Apr,Jul,Oct</th>
#     <th>NW</th>
#     <th>0</th>
#     <th>713</th>
#     <th>a</th>
#     <th>11</th>
#     <th>5</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>1</th>
#     <th>2</th>
#     <th>2014</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>0.0151</th>
#     <th>0.1991</th>
#     <th>-0.8601</th>
#     <th>0.2858</th>
#     <th>0.6155</th>
#     <th>-1.0286</th>
#     <th>-1.4366</th>
#     <th>0.0091</th>
#     <th>-0.0089</th>
#     <th>-0.6423</th>
#     <th>-0.2208</th>
#     <th>1.0334</th>
#     <th>0.7112</th>
#     <th>0.7368</th>
#     <th>-0.0321</th>
#     <th>-0.7989</th>
#     <th>-0.4785</th>
#     <th>-0.8994</th>
#     <th>-0.9252</th>
#     <th>0.6504</th>
#     <th>0.6350</th>
#     <th>1.4516</th>
#     <th>0.0054</th>
#     <th>0.2260</th>
#     <th>1.1118</

# %%
# Consider restricting sales forecasts to within 20% of the maximum seen
# As seen in 'y_range' in the call to tabular_learner below, we don't actually use this -
# in testing, it didn't help, in fact it sat on forecasts too much and hurt our rmspe
max_y = np.max(df.loc[:valid_idx[0], 'sales'])
y_range = torch.tensor([0, np.log(max_y*1.1)], device=defaults.device)

learn = tabular_learner(data, layers=[100,100], ps=[0.001, 0.01], emb_drop=0.01, metrics=exp_rmspe, y_range=y_range,
                        callback_fns=[partial(callbacks.tracker.TrackerCallback, monitor='exp_rmspe'),
                                      partial(callbacks.tracker.EarlyStoppingCallback, mode='min',
                                              monitor='exp_rmspe', min_delta=0.01, patience=1),
                                      partial(callbacks.tracker.SaveModelCallback, monitor='exp_rmspe', mode='min',
                                              every='improvement',
                                              name=datetime.now().strftime("%Y-%m-%d-%X"))])

learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
# In previous tests I found that although the learning-rate finder above might make you want to use 1e-2,
# that's too high - it diverges all the time. Instead find the rate that you want to use, then back it 
# down by a factor of ten, so 1e-3 in this case
learn.fit_one_cycle(cyc_len=10, max_lr=1e-3)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4' class='' max='10', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       40.00% [4/10 09:04<13:36]
#     </div>
#
# <table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>exp_rmspe</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.012502</th>
#     <th>0.003246</th>
#     <th>0.052192</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.008020</th>
#     <th>0.002179</th>
#     <th>0.042198</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.005588</th>
#     <th>0.001606</th>
#     <th>0.031081</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.005907</th>
#     <th>0.002645</th>
#     <th>0.035387</th>
#   </tr>
# </table>
#
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2513' class='' max='2513', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2513/2513 00:10<00:00]
#     </div>
# Epoch 5: early stopping

# %%
# Our predictions and actuals are in log form, so get them and exp them
train_log_preds, train_log_reals = learn.get_preds(ds_type=DatasetType.Train)
train_preds = np.exp(train_log_preds).flatten()
train_reals = np.exp(train_log_reals)

# Put in dataframe for easy access
train_sub = pd.DataFrame({'Predicted': train_preds, 'Actual': train_reals})

# Prepare and show chart
fig, ax = plt.subplots()
ax.scatter(train_sub.Predicted, train_sub.Actual)
ax.plot(np.linspace(0,40000,5000), np.linspace(0,40000,5000), color='black')
ax.set_title('Forecasts on the Training set')
ax.set_xlabel('Predicted sales')
ax.set_ylabel('Actual sales')
ax.set_xticklabels(['${:,.0f}'.format(x) for x in ax.get_xticks()])
ax.set_yticklabels(['${:,.0f}'.format(x) for x in ax.get_yticks()]);

# %%
def rmspe(predicted, actual):
    return np.sqrt((((actual - predicted)/actual)**2).sum()/len(actual))

rmspe(train_sub.Predicted.values, train_sub.Actual.values)
# Out:
# 0.03518582864240519

# %%
# Our predictions and actuals are in log form, so get them and exp them
log_preds, log_reals = learn.get_preds(ds_type=DatasetType.Valid)
preds = np.exp(log_preds).flatten()
reals = np.exp(log_reals)

# Put in dataframe for easy access
sub = pd.DataFrame({'Predicted': preds, 'Actual': reals})

# Prepare and show chart
fig, ax = plt.subplots()
ax.scatter(sub.Predicted, sub.Actual)
ax.plot(np.linspace(0,40000,5000), np.linspace(0,40000,5000), color='black')
ax.set_title('Forecasts on the Validation set')
ax.set_xlabel('Predicted sales')
ax.set_ylabel('Actual sales')
ax.set_xticklabels(['${:,.0f}'.format(x) for x in ax.get_xticks()])
ax.set_yticklabels(['${:,.0f}'.format(x) for x in ax.get_yticks()]);

# %%
rmspe(sub.Predicted.values, sub.Actual.values)
# Out:
# 0.030225029179863104

# %% [markdown]
# ### Re-running the store-embedding version since the first run was so bad on the training set

# %%
# Import train_valid_data and test_data dataframes
train_valid_df_raw = pd.read_csv(DATA_PATH/'train_valid_data.csv', low_memory=False)
train_valid_df = train_valid_df_raw.copy()

# Sort by date since we'll want to split by date for train/validation sets
train_valid_df.sort_values('date')

# Drop week_start and day_of_week as they'll get taken into account by add_datepart() for date
train_valid_df.drop('week_start', axis='columns', inplace=True)
train_valid_df.drop('day_of_week', axis='columns', inplace=True)

# Drop any rows where sales = 0 since we don't need to forecast those
train_valid_df = train_valid_df[train_valid_df.sales != 0]

# Run tabular.add_datepart() on both dfs to add columns about the date: ['Year', 'Month', 'Week', 'Day', 'Dayofweek',
# 'Dayofyear', 'Is_month_end', 'Is_month_start', 'Is_quarter_end', 'Is_quarter_start', 'Is_year_end', 'Is_year_start']
tabular.add_datepart(train_valid_df, 'date', drop=True, time=False)

# Category names, to which we'll apply embeddings
cat_names = ['assortment', 'events', 'promo_interval', 'state', 'state_holiday', 'store', 'store_type']

# Add the date-related categories
cat_names += ['Day', 'Dayofweek', 'Is_month_end', 'Is_month_start', 'Is_quarter_end', 'Is_quarter_start', 'Is_year_end',
              'Is_year_start', 'Month', 'Week', 'Year',]

# Continuous-variable names, which we'll make sure are all represented as floats
# Just use set difference to make sure everything is covered
cont_names = list(set(train_valid_df.columns) - set(cat_names))

# Set up transforms to 1) replace missing values for continuous variables by the median column value, 2) transform all
# categorical variables into categories, 3) normalize continuous variables.
procs = [FillMissing, Categorify, Normalize]

df = train_valid_df

# Validation set is just 80% of the whole thing
valid_idx = range(int(0.8 * len(df)), len(df))
dep_var = 'sales'

# List out the features that we don't know for predictions
unknown_in_future = ['cloud_cover', 'customers', 'dew_point_c', 'events', 'max_gust_speed_km_h', 'max_humidity',
                     'max_sea_level_pressureh_pa', 'max_temperature_c', 'max_visibility_km', 'max_wind_speed_km_h',
                     'mean_dew_point_c', 'mean_humidity', 'mean_sea_level_pressureh_pa', 'mean_temperature_c', 
                     'mean_visibility_km', 'mean_wind_speed_km_h', 'min_dew_point_c',  'min_humidity',
                     'min_sea_level_pressureh_pa', 'min_temperature_c', 'min_visibility_km', 'precipitationmm', 'trend',
                     'wind_dir_degrees']

# List of features that we know for predictions
known_in_future = set(train_valid_df.columns) - set(unknown_in_future)

print('Known: ', sorted(known_in_future), '\n')

# Make sure that features we don't know for predictions are all marked as NA in the validation set
# Our FillMissing pre-processing will account for these
train_valid_df.loc[valid_idx[0]:valid_idx[-1], unknown_in_future] = np.NaN

data = (TabularList.from_df(df, path=path, cat_names=cat_names, cont_names=cont_names, procs=procs)
                   .split_by_idx(valid_idx)
                   .label_from_df(cols=dep_var, label_cls=FloatList, log=True)
                   .databunch())

data.show_batch()
# Out:
# Known:  ['Day', 'Dayofweek', 'Dayofyear', 'Elapsed', 'Is_month_end', 'Is_month_start', 'Is_quarter_end', 'Is_quarter_start', 'Is_year_end', 'Is_year_start', 'Month', 'Week', 'Year', 'assortment', 'competition_distance', 'competition_open_since_month', 'competition_open_since_year', 'open', 'promo', 'promo2', 'promo2_since_week', 'promo2_since_year', 'promo_interval', 'sales', 'school_holiday', 'state', 'state_holiday', 'store', 'store_type']
# <table>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <tr>
#     <th>assortment</th>
#     <th>events</th>
#     <th>promo_interval</th>
#     <th>state</th>
#     <th>state_holiday</th>
#     <th>store</th>
#     <th>store_type</th>
#     <th>Day</th>
#     <th>Dayofweek</th>
#     <th>Is_month_end</th>
#     <th>Is_month_start</th>
#     <th>Is_quarter_end</th>
#     <th>Is_quarter_start</th>
#     <th>Is_year_end</th>
#     <th>Is_year_start</th>
#     <th>Month</th>
#     <th>Week</th>
#     <th>Year</th>
#     <th>precipitationmm_na</th>
#     <th>wind_dir_degrees_na</th>
#     <th>min_temperature_c_na</th>
#     <th>mean_wind_speed_km_h_na</th>
#     <th>max_visibility_km_na</th>
#     <th>cloud_cover_na</th>
#     <th>max_gust_speed_km_h_na</th>
#     <th>max_humidity_na</th>
#     <th>max_sea_level_pressureh_pa_na</th>
#     <th>trend_na</th>
#     <th>max_temperature_c_na</th>
#     <th>mean_temperature_c_na</th>
#     <th>mean_visibility_km_na</th>
#     <th>customers_na</th>
#     <th>mean_sea_level_pressureh_pa_na</th>
#     <th>min_humidity_na</th>
#     <th>dew_point_c_na</th>
#     <th>max_wind_speed_km_h_na</th>
#     <th>mean_humidity_na</th>
#     <th>min_dew_point_c_na</th>
#     <th>min_visibility_km_na</th>
#     <th>min_sea_level_pressureh_pa_na</th>
#     <th>mean_dew_point_c_na</th>
#     <th>precipitationmm</th>
#     <th>wind_dir_degrees</th>
#     <th>min_temperature_c</th>
#     <th>mean_wind_speed_km_h</th>
#     <th>max_visibility_km</th>
#     <th>cloud_cover</th>
#     <th>Dayofyear</th>
#     <th>max_gust_speed_km_h</th>
#     <th>max_humidity</th>
#     <th>competition_distance</th>
#     <th>Elapsed</th>
#     <th>promo2</th>
#     <th>max_sea_level_pressureh_pa</th>
#     <th>trend</th>
#     <th>competition_open_since_year</th>
#     <th>max_temperature_c</th>
#     <th>school_holiday</th>
#     <th>promo</th>
#     <th>mean_temperature_c</th>
#     <th>mean_visibility_km</th>
#     <th>sales</th>
#     <th>customers</th>
#     <th>competition_open_since_month</th>
#     <th>mean_sea_level_pressureh_pa</th>
#     <th>min_humidity</th>
#     <th>dew_point_c</th>
#     <th>max_wind_speed_km_h</th>
#     <th>mean_humidity</th>
#     <th>open</th>
#     <th>promo2_since_year</th>
#     <th>min_dew_point_c</th>
#     <th>min_visibility_km</th>
#     <th>min_sea_level_pressureh_pa</th>
#     <th>mean_dew_point_c</th>
#     <th>promo2_since_week</th>
#     <th>target</th>
#   </tr>
#   <tr>
#     <th>a</th>
#     <th>Rain</th>
#     <th>None</th>
#     <th>BE</th>
#     <th>0</th>
#     <th>870</th>
#     <th>a</th>
#     <th>8</th>
#     <th>0</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>12</th>
#     <th>50</th>
#     <th>2014</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>-0.3027</th>
#     <th>0.5849</th>
#     <th>-0.8601</th>
#     <th>1.0104</th>
#     <th>0.6155</th>
#     <th>-0.3403</th>
#     <th>1.7354</th>
#     <th>0.0091</th>
#     <th>0.9584</th>
#     <th>-0.5701</th>
#     <th>1.0667</th>
#     <th>-0.9677</th>
#     <th>0.0403</th>
#     <th>1.6809</th>
#     <th>0.0341</th>
#     <th>-1.0665</th>
#     <th>-0.4785</th>
#     <th>-0.8994</th>
#     <th>-1.0812</th>
#     <th>-0.2952</th>
#     <th>-0.0814</th>
#     <th>0.2698</th>
#     <th>-1.2269</th>
#     <th>-0.0317</th>
#     <th>1.0550</th>
#     <th>-0.7324</th>
#     <th>0.4343</th>
#     <th>0.9341</th>
#     <th>0.0000</th>
#     <th>0.0256</th>
#     <th>-0.9539</th>
#     <th>0.1373</th>
#     <th>-0.0241</th>
#     <th>-0.6952</th>
#     <th>-0.0432</th>
#     <th>8.828934</th>
#   </tr>
#   <tr>
#     <th>a</th>
#     <th>No Events</th>
#     <th>None</th>
#     <th>NW</th>
#     <th>0</th>
#     <th>392</th>
#     <th>a</th>
#     <th>25</th>
#     <th>0</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>3</th>
#     <th>13</th>
#     <th>2013</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>-0.3027</th>
#     <th>-1.5427</th>
#     <th>-1.7333</th>
#     <th>3.0031</th>
#     <th>0.6155</th>
#     <th>0.0391</th>
#     <th>-0.7370</th>
#     <th>1.0367</th>
#     <th>-4.7072</th>
#     <th>-0.3973</th>
#     <th>-1.3565</th>
#     <th>-0.9677</th>
#     <th>-0.3622</th>
#     <th>-0.6268</th>
#     <th>-0.0321</th>
#     <th>-1.3340</th>
#     <th>2.0899</th>
#     <th>1.1118</th>
#     <th>-1.5492</th>
#     <th>3.9598</th>
#     <th>1.5603</th>
#     <th>0.6936</th>
#     <th>0.0054</th>
#     <th>-0.1606</th>
#     <th>-1.5008</th>
#     <th>-3.0858</th>
#     <th>2.0395</th>
#     <th>-2.5369</th>
#     <th>0.0000</th>
#     <th>0.0256</th>
#     <th>-2.8107</th>
#     <th>4.3705</th>
#     <th>-0.0241</th>
#     <th>-2.9221</th>
#     <th>-0.0432</th>
#     <th>9.387984</th>
#   </tr>
#   <tr>
#     <th>c</th>
#     <th>Fog</th>
#     <th>None</th>
#     <th>SH</th>
#     <th>0</th>
#     <th>823</th>
#     <th>a</th>
#     <th>29</th>
#     <th>1</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>4</th>
#     <th>18</th>
#     <th>2014</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>-0.3027</th>
#     <th>-1.2270</th>
#     <th>-0.5107</th>
#     <th>-1.1634</th>
#     <th>0.6155</th>
#     <th>0.0391</th>
#     <th>-0.4016</th>
#     <th>0.0091</th>
#     <th>0.9584</th>
#     <th>1.4191</th>
#     <th>0.1993</th>
#     <th>-0.9677</th>
#     <th>-0.6306</th>
#     <th>0.1075</th>
#     <th>0.2338</th>
#     <th>0.6729</th>
#     <th>2.0899</th>
#     <th>1.1118</th>
#     <th>0.1669</th>
#     <th>1.3596</th>
#     <th>-0.1064</th>
#     <th>-0.3578</th>
#     <th>1.4481</th>
#     <th>-0.4183</th>
#     <th>-1.7848</th>
#     <th>-0.00

# %%
# Consider restricting sales forecasts to within 20% of the maximum seen
# As seen in 'y_range' in the call to tabular_learner below, we don't actually use this -
# in testing, it didn't help, in fact it sat on forecasts too much and hurt our rmspe
max_y = np.max(df.loc[:valid_idx[0], 'sales'])
y_range = torch.tensor([0, np.log(max_y*1.1)], device=defaults.device)

learn = tabular_learner(data, layers=[100,100], ps=[0.001, 0.01], emb_drop=0.01, metrics=exp_rmspe, y_range=y_range,
                        callback_fns=[partial(callbacks.tracker.TrackerCallback, monitor='exp_rmspe'),
                                      partial(callbacks.tracker.EarlyStoppingCallback, mode='min',
                                              monitor='exp_rmspe', min_delta=0.01, patience=1),
                                      partial(callbacks.tracker.SaveModelCallback, monitor='exp_rmspe', mode='min',
                                              every='improvement',
                                              name=datetime.now().strftime("%Y-%m-%d-%X"))])

learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
# In previous tests I found that although the learning-rate finder above might make you want to use 1e-2,
# that's too high - it diverges all the time. Instead find the rate that you want to use, then back it 
# down by a factor of ten, so 1e-3 in this case
learn.fit_one_cycle(cyc_len=10, max_lr=1e-3)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='5' class='' max='10', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       50.00% [5/10 11:24<11:24]
#     </div>
#
# <table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>exp_rmspe</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.013546</th>
#     <th>0.006978</th>
#     <th>0.080568</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.006200</th>
#     <th>0.002300</th>
#     <th>0.042942</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.006500</th>
#     <th>0.305105</th>
#     <th>0.045680</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.004659</th>
#     <th>0.001304</th>
#     <th>0.029183</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.005519</th>
#     <th>0.066199</th>
#     <th>0.046055</th>
#   </tr>
# </table>
#
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2513' class='' max='2513', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2513/2513 00:09<00:00]
#     </div>
# Epoch 6: early stopping

# %%
# Our predictions and actuals are in log form, so get them and exp them
train_log_preds, train_log_reals = learn.get_preds(ds_type=DatasetType.Train)
train_preds = np.exp(train_log_preds).flatten()
train_reals = np.exp(train_log_reals)

# Put in dataframe for easy access
train_sub = pd.DataFrame({'Predicted': train_preds, 'Actual': train_reals})

# Prepare and show chart
fig, ax = plt.subplots()
ax.scatter(train_sub.Predicted, train_sub.Actual)
ax.plot(np.linspace(0,40000,5000), np.linspace(0,40000,5000), color='black')
ax.set_title('Forecasts on the Training set')
ax.set_xlabel('Predicted sales')
ax.set_ylabel('Actual sales')
ax.set_xticklabels(['${:,.0f}'.format(x) for x in ax.get_xticks()])
ax.set_yticklabels(['${:,.0f}'.format(x) for x in ax.get_yticks()]);

# %%
def rmspe(predicted, actual):
    return np.sqrt((((actual - predicted)/actual)**2).sum()/len(actual))

rmspe(train_sub.Predicted.values, train_sub.Actual.values)
# Out:
# 0.031819324777276684

# %%
# Our predictions and actuals are in log form, so get them and exp them
log_preds, log_reals = learn.get_preds(ds_type=DatasetType.Valid)
preds = np.exp(log_preds).flatten()
reals = np.exp(log_reals)

# Put in dataframe for easy access
sub = pd.DataFrame({'Predicted': preds, 'Actual': reals})

# Prepare and show chart
fig, ax = plt.subplots()
ax.scatter(sub.Predicted, sub.Actual)
ax.plot(np.linspace(0,40000,5000), np.linspace(0,40000,5000), color='black')
ax.set_title('Forecasts on the Validation set')
ax.set_xlabel('Predicted sales')
ax.set_ylabel('Actual sales')
ax.set_xticklabels(['${:,.0f}'.format(x) for x in ax.get_xticks()])
ax.set_yticklabels(['${:,.0f}'.format(x) for x in ax.get_yticks()]);

# %%
rmspe(sub.Predicted.values, sub.Actual.values)
# Out:
# 0.039189851826395075

# %% [markdown]
# ### Trying with y_range = 1.1, no store embedding

# %%
# Import train_valid_data and test_data dataframes
train_valid_df_raw = pd.read_csv(DATA_PATH/'train_valid_data.csv', low_memory=False)
train_valid_df = train_valid_df_raw.copy()

# Sort by date since we'll want to split by date for train/validation sets
train_valid_df.sort_values('date')

# Drop week_start and day_of_week as they'll get taken into account by add_datepart() for date
train_valid_df.drop('week_start', axis='columns', inplace=True)
train_valid_df.drop('day_of_week', axis='columns', inplace=True)

# Drop any rows where sales = 0 since we don't need to forecast those
train_valid_df = train_valid_df[train_valid_df.sales != 0]

# Run tabular.add_datepart() on both dfs to add columns about the date: ['Year', 'Month', 'Week', 'Day', 'Dayofweek',
# 'Dayofyear', 'Is_month_end', 'Is_month_start', 'Is_quarter_end', 'Is_quarter_start', 'Is_year_end', 'Is_year_start']
tabular.add_datepart(train_valid_df, 'date', drop=True, time=False)

# Category names, to which we'll apply embeddings
cat_names = ['assortment', 'events', 'promo_interval', 'state', 'state_holiday', 'store_type']

# Add the date-related categories
cat_names += ['Day', 'Dayofweek', 'Is_month_end', 'Is_month_start', 'Is_quarter_end', 'Is_quarter_start', 'Is_year_end',
              'Is_year_start', 'Month', 'Week', 'Year',]

# Continuous-variable names, which we'll make sure are all represented as floats
# Just use set difference to make sure everything is covered
cont_names = list(set(train_valid_df.columns) - set(cat_names))

# Set up transforms to 1) replace missing values for continuous variables by the median column value, 2) transform all
# categorical variables into categories, 3) normalize continuous variables.
procs = [FillMissing, Categorify, Normalize]

df = train_valid_df

# Validation set is just 80% of the whole thing
valid_idx = range(int(0.8 * len(df)), len(df))
dep_var = 'sales'

# List out the features that we don't know for predictions
unknown_in_future = ['cloud_cover', 'customers', 'dew_point_c', 'events', 'max_gust_speed_km_h', 'max_humidity',
                     'max_sea_level_pressureh_pa', 'max_temperature_c', 'max_visibility_km', 'max_wind_speed_km_h',
                     'mean_dew_point_c', 'mean_humidity', 'mean_sea_level_pressureh_pa', 'mean_temperature_c', 
                     'mean_visibility_km', 'mean_wind_speed_km_h', 'min_dew_point_c',  'min_humidity',
                     'min_sea_level_pressureh_pa', 'min_temperature_c', 'min_visibility_km', 'precipitationmm', 'trend',
                     'wind_dir_degrees']

# List of features that we know for predictions
known_in_future = set(train_valid_df.columns) - set(unknown_in_future)

print('Known: ', sorted(known_in_future), '\n')

# Make sure that features we don't know for predictions are all marked as NA in the validation set
# Our FillMissing pre-processing will account for these
train_valid_df.loc[valid_idx[0]:valid_idx[-1], unknown_in_future] = np.NaN

data = (TabularList.from_df(df, path=path, cat_names=cat_names, cont_names=cont_names, procs=procs)
                   .split_by_idx(valid_idx)
                   .label_from_df(cols=dep_var, label_cls=FloatList, log=True)
                   .databunch())

data.show_batch()
# Out:
# Known:  ['Day', 'Dayofweek', 'Dayofyear', 'Elapsed', 'Is_month_end', 'Is_month_start', 'Is_quarter_end', 'Is_quarter_start', 'Is_year_end', 'Is_year_start', 'Month', 'Week', 'Year', 'assortment', 'competition_distance', 'competition_open_since_month', 'competition_open_since_year', 'open', 'promo', 'promo2', 'promo2_since_week', 'promo2_since_year', 'promo_interval', 'sales', 'school_holiday', 'state', 'state_holiday', 'store', 'store_type']
# <table>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <tr>
#     <th>assortment</th>
#     <th>events</th>
#     <th>promo_interval</th>
#     <th>state</th>
#     <th>state_holiday</th>
#     <th>store_type</th>
#     <th>Day</th>
#     <th>Dayofweek</th>
#     <th>Is_month_end</th>
#     <th>Is_month_start</th>
#     <th>Is_quarter_end</th>
#     <th>Is_quarter_start</th>
#     <th>Is_year_end</th>
#     <th>Is_year_start</th>
#     <th>Month</th>
#     <th>Week</th>
#     <th>Year</th>
#     <th>precipitationmm_na</th>
#     <th>wind_dir_degrees_na</th>
#     <th>min_temperature_c_na</th>
#     <th>mean_wind_speed_km_h_na</th>
#     <th>max_visibility_km_na</th>
#     <th>cloud_cover_na</th>
#     <th>max_gust_speed_km_h_na</th>
#     <th>max_humidity_na</th>
#     <th>max_sea_level_pressureh_pa_na</th>
#     <th>trend_na</th>
#     <th>max_temperature_c_na</th>
#     <th>mean_temperature_c_na</th>
#     <th>mean_visibility_km_na</th>
#     <th>customers_na</th>
#     <th>mean_sea_level_pressureh_pa_na</th>
#     <th>min_humidity_na</th>
#     <th>dew_point_c_na</th>
#     <th>max_wind_speed_km_h_na</th>
#     <th>mean_humidity_na</th>
#     <th>min_dew_point_c_na</th>
#     <th>min_visibility_km_na</th>
#     <th>min_sea_level_pressureh_pa_na</th>
#     <th>mean_dew_point_c_na</th>
#     <th>precipitationmm</th>
#     <th>wind_dir_degrees</th>
#     <th>min_temperature_c</th>
#     <th>mean_wind_speed_km_h</th>
#     <th>max_visibility_km</th>
#     <th>cloud_cover</th>
#     <th>Dayofyear</th>
#     <th>max_gust_speed_km_h</th>
#     <th>max_humidity</th>
#     <th>competition_distance</th>
#     <th>Elapsed</th>
#     <th>promo2</th>
#     <th>max_sea_level_pressureh_pa</th>
#     <th>trend</th>
#     <th>competition_open_since_year</th>
#     <th>max_temperature_c</th>
#     <th>school_holiday</th>
#     <th>promo</th>
#     <th>mean_temperature_c</th>
#     <th>store</th>
#     <th>mean_visibility_km</th>
#     <th>sales</th>
#     <th>customers</th>
#     <th>competition_open_since_month</th>
#     <th>mean_sea_level_pressureh_pa</th>
#     <th>min_humidity</th>
#     <th>dew_point_c</th>
#     <th>max_wind_speed_km_h</th>
#     <th>mean_humidity</th>
#     <th>open</th>
#     <th>promo2_since_year</th>
#     <th>min_dew_point_c</th>
#     <th>min_visibility_km</th>
#     <th>min_sea_level_pressureh_pa</th>
#     <th>mean_dew_point_c</th>
#     <th>promo2_since_week</th>
#     <th>target</th>
#   </tr>
#   <tr>
#     <th>a</th>
#     <th>#na#</th>
#     <th>None</th>
#     <th>HB,NI</th>
#     <th>0</th>
#     <th>a</th>
#     <th>5</th>
#     <th>3</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>12</th>
#     <th>49</th>
#     <th>2013</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>True</th>
#     <th>-0.3027</th>
#     <th>0.1757</th>
#     <th>0.0132</th>
#     <th>-0.2577</th>
#     <th>0.6155</th>
#     <th>0.3479</th>
#     <th>1.7066</th>
#     <th>0.0091</th>
#     <th>0.1293</th>
#     <th>-0.6642</th>
#     <th>-0.3647</th>
#     <th>-0.9677</th>
#     <th>0.0403</th>
#     <th>-0.1023</th>
#     <th>-0.0321</th>
#     <th>0.0039</th>
#     <th>-0.4785</th>
#     <th>1.1118</th>
#     <th>0.0109</th>
#     <th>0.4927</th>
#     <th>-0.0588</th>
#     <th>1.1813</th>
#     <th>-0.1948</th>
#     <th>0.0054</th>
#     <th>-0.0317</th>
#     <th>-0.0241</th>
#     <th>-0.0083</th>
#     <th>-0.0596</th>
#     <th>0.0875</th>
#     <th>0.0000</th>
#     <th>0.0256</th>
#     <th>-0.0256</th>
#     <th>0.1373</th>
#     <th>-0.0241</th>
#     <th>0.0471</th>
#     <th>-0.0432</th>
#     <th>9.28387</th>
#   </tr>
#   <tr>
#     <th>a</th>
#     <th>Fog-Rain</th>
#     <th>None</th>
#     <th>BE</th>
#     <th>0</th>
#     <th>a</th>
#     <th>25</th>
#     <th>2</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>9</th>
#     <th>39</th>
#     <th>2013</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>-0.3027</th>
#     <th>-1.1686</th>
#     <th>0.0132</th>
#     <th>-1.1634</th>
#     <th>0.6155</th>
#     <th>0.3479</th>
#     <th>1.0262</th>
#     <th>0.0091</th>
#     <th>0.9584</th>
#     <th>-0.6062</th>
#     <th>-0.6408</th>
#     <th>-0.9677</th>
#     <th>-0.3622</th>
#     <th>0.1075</th>
#     <th>0.2338</th>
#     <th>-0.1299</th>
#     <th>-0.4785</th>
#     <th>1.1118</th>
#     <th>-0.1451</th>
#     <th>0.4525</th>
#     <th>-0.0588</th>
#     <th>1.3944</th>
#     <th>1.6852</th>
#     <th>1.8303</th>
#     <th>-0.1606</th>
#     <th>0.2598</th>
#     <th>0.5347</th>
#     <th>-0.3066</th>
#     <th>0.5954</th>
#     <th>0.0000</th>
#     <th>0.0256</th>
#     <th>0.3458</th>
#     <th>-1.2738</th>
#     <th>-0.2671</th>
#     <th>0.2327</th>
#     <th>-0.0432</th>
#     <th>9.343735</th>
#   </tr>
#   <tr>
#     <th>a</th>
#     <th>Rain</th>
#     <th>Jan,Apr,Jul,Oct</th>
#     <th>TH</th>
#     <th>0</th>
#     <th>a</th>
#     <th>28</th>
#     <th>0</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>10</th>
#     <th>44</th>
#     <th>2013</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>False</th>
#     <th>-0.3027</th>
#     <th>0.4095</th>
#     <th>0.8865</th>
#     <th>4.0900</th>
#     <th>-2.0716</th>
#     <th>-0.3403</th>
#     <th>1.3425</th>
#     <th>5.5587</th>
#     <th>-0.6998</th>
#     <th>-0.5971</th>
#     <th>-0.5125</th>
#     <th>1.0334</th>
#     <th>-1.4357</th>
#     <th>-1.4659</th>
#     <th>-0.3655</th>
#     <th>0.6729</th>
#     <th>2.0899</th>
#     <th>-0.8994</th>
#     <th>0.6350</th>
#     <th>-1.7345</th>
#     <th>-0.5315</th>
#     <th>-1.0346</th>
#     <th>-0.6947</th>
#     <th>1.4481</th>
#     <th>-1.7067</th>
#     <th>-0.4785</th>
#     <th>0.5347

# %%
# Consider restricting sales forecasts to within 20% of the maximum seen
# As seen in 'y_range' in the call to tabular_learner below, we don't actually use this -
# in testing, it didn't help, in fact it sat on forecasts too much and hurt our rmspe
max_y = np.max(df.loc[:valid_idx[0], 'sales'])
y_range = torch.tensor([0, np.log(max_y*1.1)], device=defaults.device)

learn = tabular_learner(data, layers=[100,100], ps=[0.001, 0.01], emb_drop=0.01, metrics=exp_rmspe, y_range=y_range,
                        callback_fns=[partial(callbacks.tracker.TrackerCallback, monitor='exp_rmspe'),
                                      partial(callbacks.tracker.EarlyStoppingCallback, mode='min',
                                              monitor='exp_rmspe', min_delta=0.01, patience=1),
                                      partial(callbacks.tracker.SaveModelCallback, monitor='exp_rmspe', mode='min',
                                              every='improvement',
                                              name=datetime.now().strftime("%Y-%m-%d-%X"))])

learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
# In previous tests I found that although the learning-rate finder above might make you want to use 1e-2,
# that's too high - it diverges all the time. Instead find the rate that you want to use, then back it 
# down by a factor of ten, so 1e-3 in this case
learn.fit_one_cycle(cyc_len=10, max_lr=1e-3)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3' class='' max='10', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       30.00% [3/10 06:42<15:40]
#     </div>
#
# <table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>exp_rmspe</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.011467</th>
#     <th>0.003389</th>
#     <th>0.054420</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.005684</th>
#     <th>0.001463</th>
#     <th>0.035851</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.005930</th>
#     <th>0.001357</th>
#     <th>0.033738</th>
#   </tr>
# </table>
#
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2513' class='' max='2513', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2513/2513 00:09<00:00]
#     </div>
# Epoch 4: early stopping

# %%
# Our predictions and actuals are in log form, so get them and exp them
train_log_preds, train_log_reals = learn.get_preds(ds_type=DatasetType.Train)
train_preds = np.exp(train_log_preds).flatten()
train_reals = np.exp(train_log_reals)

# Put in dataframe for easy access
train_sub = pd.DataFrame({'Predicted': train_preds, 'Actual': train_reals})

# Prepare and show chart
fig, ax = plt.subplots()
ax.scatter(train_sub.Predicted, train_sub.Actual)
ax.plot(np.linspace(0,40000,5000), np.linspace(0,40000,5000), color='black')
ax.set_title('Forecasts on the Training set')
ax.set_xlabel('Predicted sales')
ax.set_ylabel('Actual sales')
ax.set_xticklabels(['${:,.0f}'.format(x) for x in ax.get_xticks()])
ax.set_yticklabels(['${:,.0f}'.format(x) for x in ax.get_yticks()]);

# %%
def rmspe(predicted, actual):
    return np.sqrt((((actual - predicted)/actual)**2).sum()/len(actual))

rmspe(train_sub.Predicted.values, train_sub.Actual.values)
# Out:
# 0.0442320639454232

# %%
# Our predictions and actuals are in log form, so get them and exp them
log_preds, log_reals = learn.get_preds(ds_type=DatasetType.Valid)
preds = np.exp(log_preds).flatten()
reals = np.exp(log_reals)

# Put in dataframe for easy access
sub = pd.DataFrame({'Predicted': preds, 'Actual': reals})

# Prepare and show chart
fig, ax = plt.subplots()
ax.scatter(sub.Predicted, sub.Actual)
ax.plot(np.linspace(0,40000,5000), np.linspace(0,40000,5000), color='black')
ax.set_title('Forecasts on the Validation set')
ax.set_xlabel('Predicted sales')
ax.set_ylabel('Actual sales')
ax.set_xticklabels(['${:,.0f}'.format(x) for x in ax.get_xticks()])
ax.set_yticklabels(['${:,.0f}'.format(x) for x in ax.get_yticks()]);

# %%
rmspe(sub.Predicted.values, sub.Actual.values)
# Out:
# 0.046936999691351705

# %% [markdown]
# ### Finish from the bottom here once done

# %%
learn.path
# Out:
# PosixPath('../../models')

# %%
learn.save('bad_model_do_not_use_0.0465')
learn.export('bad_model_do_not_use_0.0465')

# %%
# Redoing the training-set transforms for the test set
# Yes this is copy/paste - three strikes and you're out, here we have a full count :)

# Import test_data dataframe and prep for use
test_df_raw = pd.read_csv(DATA_PATH/'test_data.csv', low_memory=False)
test_df = test_df_raw.copy()

# Drop week_start as that will get taken into account by add_datepart() for date
test_df.drop('week_start', axis='columns', inplace=True)

# Drop any rows where sales = 0 since we don't need to forecast those
test_df = test_df[test_df.sales != 0]

# Run tabular.add_datepart() on both dfs to add columns about the date: ['Year', 'Month', 'Week', 'Day', 'Dayofweek',
# 'Dayofyear', 'Is_month_end', 'Is_month_start', 'Is_quarter_end', 'Is_quarter_start', 'Is_year_end', 'Is_year_start']
tabular.add_datepart(test_df, 'date', drop=True, time=False)

# Category names, to which we'll apply embeddings
cat_names = ['assortment', 'events', 'promo_interval', 'state', 'state_holiday', 'store_type']

# Add the date-related categories
cat_names += ['Day', 'Dayofweek', 'Is_month_end', 'Is_month_start', 'Is_quarter_end', 'Is_quarter_start', 'Is_year_end',
              'Is_year_start', 'Month', 'Week', 'Year',]

# Continuous-variable names, which we'll make sure are all represented as floats
# Just use set difference to make sure everything is covered
cont_names = list(set(train_valid_df.columns) - set(cat_names))

# Set up transforms to 1) replace missing values for continuous variables by the median column value, 2) transform all
# categorical variables into categories, 3) normalize continuous variables.
# Note that FillMissing should do nothing since we shouldn't have any NaNs -- leaving it in anyway
procs = [FillMissing, Categorify, Normalize]

# %%
learn = load_learner(path='../../models/', fname='bad_model_do_not_use_0.0465.pkl',
                      test=TabularList.from_df(test_df, path=path))

# %%
log_test_preds, log_test_reals = learn.get_preds(ds_type=DatasetType.Test)
test_preds = np.exp(log_test_preds).flatten()
#test_reals = np.exp(log_test_reals)
test_reals = test_df_raw.loc[test_df_raw.sales != 0, 'sales'].values
test_sub = pd.DataFrame({'Predicted': test_preds, 'Actual': test_reals})
fig, ax = plt.subplots()
ax.scatter(test_sub.Predicted, test_sub.Actual)
ax.plot(np.linspace(0,40000,5000), np.linspace(0,40000,5000), color='black')
ax.set_title('Forecasts on the Test set')
ax.set_xlabel('Predicted sales')
ax.set_ylabel('Actual sales')
ax.set_xticklabels(['${:,.0f}'.format(x) for x in ax.get_xticks()])
ax.set_yticklabels(['${:,.0f}'.format(x) for x in ax.get_yticks()]);

# %%
rmspe(test_sub.Predicted.values, test_sub.Actual.values)
# Out:
# 0.03751727971967949

# %%
wrongs = test_sub[np.abs((test_sub.Predicted - test_sub.Actual) / test_sub.Actual) > 0.1]
#len(wrongs)/len(test_sub) # 0.0205
#len(wrongs) # 827

# Create and display the chart
fig, ax = plt.subplots()
ax.scatter(wrongs.Predicted, wrongs.Actual)
ax.plot(np.linspace(0,40000,5000), np.linspace(0,40000,5000), color='black')
ax.set_title('Forecasts on the Test Set that are Wrong by > 10%')
ax.set_xlabel('Predicted sales')
ax.set_ylabel('Actual sales')
ax.set_xticklabels(['${:,.0f}'.format(x) for x in ax.get_xticks()])
ax.set_yticklabels(['${:,.0f}'.format(x) for x in ax.get_yticks()]);

# %%
wrong_and_big = test_sub[(np.abs((test_sub.Predicted - test_sub.Actual) / test_sub.Actual) > 0.1) &
                         (test_sub.Actual > 10000)]
len(wrong_and_big) # 22
#plt.scatter(wrong_and_big.Predicted, wrong_and_big.Actual)
# Out:
# 377

# %%
close = test_sub[np.abs((test_sub.Predicted - test_sub.Actual) / test_sub.Actual) < 0.01]
len(close)/len(test_sub) # 0.1657564172583288
len(close) # 6677

# Create and display the chart
fig, ax = plt.subplots()
ax.scatter(close.Predicted, close.Actual)
ax.plot(np.linspace(0,40000,5000), np.linspace(0,40000,5000), color='black')
ax.set_title('Forecasts on the Test Set that are Wrong by < 1%')
ax.set_xlabel('Predicted sales')
ax.set_ylabel('Actual sales')
ax.set_xticklabels(['${:,.0f}'.format(x) for x in ax.get_xticks()])
ax.set_yticklabels(['${:,.0f}'.format(x) for x in ax.get_yticks()]);

# %%
test_sub.head(15)
# Out:
#       Predicted  Actual
# 0   4144.839844  4097.0
# 1   8937.591797  9351.0
# 2   6711.314453  6895.0
# 3   7364.810059  7656.0
# 4   5893.949707  6039.0
# 5   5107.802734  5135.0
# 6   7307.001953  7604.0
# 7   4348.073242  4318.0
# 8   5735.626953  5823.0
# 9   6008.357910  6125.0
# 10  7786.768555  8127.0
# 11  4895.636230  4872.0
# 12  6239.552246  6380.0
# 13  5924.380859  5935.0
# 14  6392.381836  6557.0
